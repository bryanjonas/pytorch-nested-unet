# %%
from skimage.io import imread
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.preprocessing import robust_scale

# %%
train_path = '/data/spacenet/bldg/data/pytorch-PAN/images/PAN_AOI_2_Vegas_img1000.tif'
img = imread(train_path)
img.shape
#img = (img - img.mean()) / img.std()
#img_h = img.flatten()
#ax = sns.displot(img_h, stat = 'density')
#ax.set(xlim=(-5, 5))
# Out:
# (650, 650)

# %%
img2 = imread('20NOV16160831-P3DS-013365548010_01_P001.TIF')
#img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

img2 = (img2 - img2.mean()) / img2.std()
img2_h = img2.flatten()
#img2 = np.tanh(((img2 - img2.mean()))/img2.std())
ax = sns.displot(img2_h, stat="density")
ax.set(xlim=(-5,5))

# %%
img2.shape
# Out:
# (3739, 6523)

# %%
plt.imshow(img2)
